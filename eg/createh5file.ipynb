# %%
#!/usr/bin/env python3
import numpy as np
import h5py

def main():

    E_50 = np.linspace(1, 0.01, 51)
    E_grid_50 = np.column_stack((E_50[:-1], E_50[1:]))

    xs_a_50 = np.array([2.27418E-04,  2.45855E-04,  2.46269E-04,  2.50741E-04,  2.57984E-04,  2.57151E-04,  2.79860E-04,  2.89205E-04, 2.81906E-04,  2.96651E-04,  2.99901E-04,  3.10618E-04,  3.15408E-04,  3.39896E-04,  2.97606E-04,  3.07739E-04,
        2.95290E-04,  3.16050E-04,  2.86846E-04,  2.88778E-04,  3.03885E-04,  3.23915E-04,  3.39852E-04,  3.21681E-04, 3.20325E-04,  3.30874E-04,  3.46433E-04,  3.10682E-04,  3.37842E-04, 3.72998E-04,  3.86048E-04,  4.66812E-04, 5.09680E-04,  5.92211E-04, 
        6.61295E-04,  7.53455E-04,  8.95965E-04,  1.04145E-03,  1.28112E-03,  1.55454E-03, 1.91991E-03,  2.50250E-03,  3.38605E-03, 4.60680E-03,  6.57085E-03,  9.82564E-03,  1.69755E-02,  3.47682E-02, 9.96159E-02,  0.00000E+00])
    
    xs_s_50 = np.array([8.48366E+01,  8.73902E+01,  9.00740E+01,  9.28975E+01,  9.58713E+01,  9.90069E+01,  1.02317E+02,  1.05817E+02,  1.09520E+02,  1.13446E+02,  1.17613E+02,  1.22043E+02,  1.26760E+02,
        1.31792E+02,  1.37169E+02,  1.42926E+02,  1.49102E+02,  1.55742E+02,  1.62897E+02,  1.70627E+02,  1.79000E+02,  1.88054E+02,  1.97956E+02,  2.08779E+02,  2.20651E+02,  2.33722E+02,
        2.48171E+02,  2.64214E+02,  2.82113E+02,  3.02188E+02,  3.24834E+02,  3.50521E+02,  3.79895E+02,  4.13748E+02,  4.53110E+02,  4.99333E+02,  5.54229E+02,  6.20274E+02,  6.83135E+02, 
        7.80684E+02,  9.04414E+02,  1.06531E+03,  1.28105E+03,  1.58170E+03,  2.02220E+03,  2.71280E+03,  3.90508E+03,  6.28319E+03,  1.22763E+04,  3.83817E+04])

    S_50 = np.array([3.11655E+00, 3.12384E+00,  3.13157E+00,  3.13944E+00,  3.14808E+00,  3.15731E+00,  3.16712E+00,  3.17717E+00, 3.18821E+00,  3.20003E+00,  3.21262E+00,  3.22562E+00,
        3.23996E+00,  3.25532E+00,  3.27128E+00,  3.28886E+00, 3.30779E+00,  3.32760E+00,  3.34946E+00,  3.37308E+00,  3.39799E+00,  3.42560E+00,  3.45499E+00,  3.48744E+00,
        3.52291E+00,  3.56093E+00,  3.60336E+00,  3.65006E+00,  3.69961E+00,  3.75117E+00,  3.81007E+00,  3.87505E+00, 3.94829E+00,  4.03204E+00,  4.12628E+00,  4.23427E+00,  
        4.35901E+00,  4.50514E+00,  4.67577E+00,  4.87869E+00, 5.12344E+00,  5.42210E+00,  5.79788E+00,  6.27924E+00,  6.92120E+00,  7.81204E+00,  9.13207E+00,  1.12705E+01,
        1.46400E+01,  2.68083E+01] )
    
    
    E_100 = np.linspace(1, 0.01, 101)
    E_grid_100 = np.column_stack((E_100[:-1], E_100[1:]))

        3.74892E+02,  3.90747E+02,  4.07784E+02,  4.26133E+02,  4.45941E+02,  4.67376E+02,  4.90633E+02,  5.15938E+02, 5.43555E+02,  5.73791E+02,  6.07009E+02,  6.27367E+02,  6.66845E+02,  7.10739E+02,  7.59771E+02,  8.14824E+02,
        8.76986E+02,  9.47608E+02,  1.02839E+03,  1.12150E+03,  1.22971E+03,  1.35670E+03,  1.50732E+03,  1.68818E+03, 1.90844E+03,  2.18114E+03,  2.52536E+03,  2.97008E+03,  3.56110E+03,  4.37461E+03,  5.54576E+03,  7.30047E+03,
        1.01657E+04,  1.54165E+04,  2.67979E+04,  6.13355E+04])

    S_100 = np.array([2.95827E+00,  2.96158E+00,  2.96500E+00,  2.96852E+00,  2.97213E+00,  2.97585E+00,  2.97937E+00,  2.98329E+00, 2.98735E+00,  2.99155E+00,  2.99588E+00,  3.00034E+00,  3.00494E+00,  3.00968E+00,  3.01421E+00,  3.01922E+00,
        3.02442E+00,  3.02980E+00,  3.03537E+00,  3.04110E+00,  3.04702E+00,  3.05275E+00,  3.05902E+00,  3.06554E+00, 3.07230E+00,  3.07929E+00,  3.08652E+00,  3.09399E+00,  3.10127E+00,  3.10926E+00,  3.11755E+00,  3.12616E+00,
        3.13509E+00,  3.14432E+00,  3.15341E+00,  3.16332E+00,  3.17365E+00,  3.18438E+00,  3.19553E+00,  3.20710E+00, 3.21858E+00,  3.23109E+00,  3.24413E+00,  3.25772E+00,  3.27184E+00,  3.28598E+00,  3.30133E+00,  3.31739E+00,
        3.33416E+00,  3.35105E+00,  3.36928E+00,  3.38843E+00,  3.40851E+00,  3.42950E+00,  3.45177E+00,  3.47437E+00, 3.49767E+00,  3.52166E+00,  3.54505E+00,  3.57133E+00,  3.59910E+00,  3.62760E+00,  3.65859E+00,  3.69155E+00,
        3.72569E+00,  3.76269E+00,  3.80225E+00,  3.84351E+00,  3.88831E+00,  3.93641E+00,  3.98687E+00,  4.04200E+00, 4.10140E+00,  4.16417E+00,  4.23327E+00,  4.30681E+00,  4.38793E+00,  4.47499E+00,  4.57136E+00,  4.67566E+00,
        4.79185E+00,  4.91866E+00,  5.06115E+00,  5.21832E+00,  5.39478E+00,  5.59592E+00,  5.82273E+00,  6.08284E+00, 6.38411E+00,  6.73691E+00,  7.15544E+00,  7.65979E+00,  8.27897E+00,  9.05349E+00,  1.00603E+01,  1.14110E+01,
        1.33246E+01,  1.62704E+01,  2.10300E+01,  3.32745E+01])
    
    
    output_filename = "data.h5"

    with h5py.File(output_filename, 'w') as hf:
        hf.create_dataset("E_50", data=E_50)
        hf.create_dataset("E_grid_50", data=E_grid_50)
        hf.create_dataset("xs_t_50", data = (xs_a_50 + xs_s_50))
        hf.create_dataset("xs_s_50", data = xs_s_50)
        hf.create_dataset("S_50",    data = S_50 * 2.710)
        hf.create_dataset("E_100", data = E_100)
        hf.create_dataset("E_grid_100", data = E_grid_100)
        hf.create_dataset("xs_t_100", data = (xs_a_100 + xs_s_100))
        hf.create_dataset("xs_s_100", data = xs_s_100)
        hf.create_dataset("S_100",    data = S_100 * 2.710)

    print(f"{output_filename} has been successfully created.")

if __name__ == "__main__":
    main()
# Out:
# data.h5 has been successfully created.
